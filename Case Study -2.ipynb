# %%
import pandas as pd

# %%
df = pd.read_csv('Salaries.csv')
# Out:
# C:\Users\kotesh\AppData\Local\Temp\ipykernel_17576\2827120379.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Salaries.csv')

# %% [markdown]
# ####  Display Top 10 Rows of The Dataset

# %%
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %% [markdown]
# ####  Check Last 10 Rows of The Dataset

# %%
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# #### Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
a = df.shape
print("Number of Rows :",a[0])
print("Number of Columns :",a[1])
# Out:
# Number of Rows : 148654
# Number of Columns : 13

# %% [markdown]
# ####  Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# #### Check Null Values In The Dataset

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
import seaborn as sn

# %%
sn.heatmap(df.isnull())   # the white spots area is null values
# Out:
# <Axes: >

# %% [markdown]
# #### Drop ID, Notes, Agency, and Status Columns

# %%
df.drop(['Id', 'Notes', 'Agency', 'Status'],axis=1,inplace=True)

# %%
df.sample(10)
# Out:
#                    EmployeeName                        JobTitle    BasePay  \
# 26094        GEORGE DEL-ROSARIO             FOOD SERVICE WORKER   42020.84
# 105323           Jose G Jimenez  StdntDsgnTrain1, Arch/Eng/Plng    11829.2
# 74943   Katherine  Schwarz-Choy                      Sergeant 2   140724.0
# 105246           Alvin H Torres               Recreation Leader   12902.84
# 111455          Robert D Gallot         Fire Safety Inspector 2   134472.0
# 139778           Chanelle Wells                           Clerk   23614.82
# 27162         KIMBERLY WILLIAMS    AIRPORT POLICE SERVICES AIDE    33431.5
# 137569          Savitree Satram      Senior Food Service Worker   26539.69
# 82296         Brandon W Chatham       EMT/Paramedic/Firefighter  105135.13
# 3744               NELLIE SARTE                REGISTERED NURSE   115882.0
#
#        OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# ...

# %% [markdown]
# #### Get Overall Statistics About The Dataframe

# %%
df.describe()
# Out:
#             TotalPay  TotalPayBenefits           Year
# count  148654.000000     148654.000000  148654.000000
# mean    74768.321972      93692.554811    2012.522643
# std     50517.005274      62793.533483       1.117538
# min      -618.130000       -618.130000    2011.000000
# 25%     36168.995000      44065.650000    2012.000000
# 50%     71426.610000      92404.090000    2013.000000
# 75%    105839.135000     132876.450000    2014.000000
# max    567595.430000     567595.430000    2014.000000

# %%
df.describe(include='all')
# Out:
#        EmployeeName          JobTitle   BasePay  OvertimePay  OtherPay  \
# count        148654            148654  148049.0     148654.0  148654.0
# unique       110811              2159  109900.0      66555.0   84968.0
# top       Kevin Lee  Transit Operator       0.0          0.0       0.0
# freq             13              7036     875.0      66103.0   35218.0
# mean            NaN               NaN       NaN          NaN       NaN
# std             NaN               NaN       NaN          NaN       NaN
# min             NaN               NaN       NaN          NaN       NaN
# 25%             NaN               NaN       NaN          NaN       NaN
# 50%             NaN               NaN       NaN          NaN       NaN
# 75%             NaN               NaN       NaN          NaN       NaN
# max             NaN               NaN       NaN          NaN       NaN
#
#         Benefits       TotalPay  TotalPayBenefits           Year
# ...

# %% [markdown]
# ####  Find Occurrence of The Employee Names  (Top 5)

# %%
df['EmployeeName'].value_counts()   # Repeated names of the employee's
# Out:
# EmployeeName
# Kevin Lee                   13
# Richard Lee                 11
# Steven Lee                  11
# William Wong                11
# Stanley Lee                  9
#                             ..
# Jeffrey Skover               1
# Ken Dever                    1
# Kevin Whitfield              1
# Granville McCollough III     1
# Joe Lopez                    1
# Name: count, Length: 110811, dtype: int64

# %% [markdown]
# ####  Find The Number of Unique Job Titles

# %%
df['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
len(df['JobTitle'].unique())
# Out:
# 2159

# %% [markdown]
# #### Total Number of Job Titles Contain Captain

# %%
df[df['JobTitle'].str.contains('Captain', case = False)]
# Out:
#               EmployeeName                               JobTitle    BasePay  \
# 1             GARY JIMENEZ        CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2           ALBERT PARDINI        CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 11        PATRICIA JACKSON        CAPTAIN III (POLICE DEPARTMENT)    99722.0
# 17          SEBASTIAN WONG  CAPTAIN, EMERGENCYCY MEDICAL SERVICES  140546.87
# 22           GEORGE GARCIA              CAPTAIN, FIRE SUPPRESSION  140546.88
# ...                    ...                                    ...        ...
# 116604   Gregory L Stewart              Captain, Fire Suppression   73355.21
# 120867     Michael J Moran                              Captain 3     7660.0
# 122361  Michael V Rolovich              Captain, Fire Suppression        0.0
# 126588    Stephen M Tittel                              Captain 3   68491.89
# 132232     Jeanne M Seyler              Captain, Fire Suppression   61039.43
#
# ...

# %%
len(df[df['JobTitle'].str.contains('Captain',case=False)])
# Out:
# 552

# %% [markdown]
# #### Display All the Employee Names From Fire Department

# %%
df[df['JobTitle'].str.contains('FIRE DEPARTMENT',case=False)][['EmployeeName']]
# Out:
#                 EmployeeName
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
# ...                      ...
# 32623           JAMES BARDEN
# 36162     Joanne Hayes-White
# 72926   Joanne M Hayes-White
# 102303        Robert E Evans
# 110535  Joanne M Hayes-White
#
# [226 rows x 1 columns]

# %% [markdown]
# ####  Find Minimum, Maximum, and Average BasePay

# %%
df['BasePay'].describe()
# Out:
# count     148049.0
# unique    109900.0
# top            0.0
# freq         875.0
# Name: BasePay, dtype: float64

# %% [markdown]
# #### Replace 'Not Provided' in EmployeeName' Column to NaN

# %%
import numpy as np

# %%
df['EmployeeName'].replace('Not provided',np.nan,inplace=True)

# %%
df['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %% [markdown]
# #### Drop The Rows Having 5 Missing Values

# %%
len(df[df.isnull().sum(axis=1)==5])
# Out:
# 0

# %% [markdown]
# #### Find Job Title of ALBERT PARDINI

# %%
df[df['EmployeeName'] == 'ALBERT PARDINI']['JobTitle']
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
import numpy as np

# %%
df['BasePay'].replace('Not provided', np.NaN, inplace=True)

# %%
df.replace('NaN',np.NaN,inplace=True)

# %% [markdown]
# ####  Find Top 5 Most Common Jobs

# %%
df['JobTitle'].value_counts().head()
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %% [markdown]
# ### Case Study - 3

# %% [markdown]
# In this project, we will discuss:
# - How to fetch random samples from the Dataset?
# - isin
# - between
# - unique
# - dropna
# - replace
# - duplicated
# - drop_duplicates
# - astype
# - apply
# - What is Univariate analysis?
# - What is Bivariate analysis?
# - Memory Optimization

# %%
import pandas as pd
import numpy as np

# %%
dt = pd.read_csv('adult.csv')

# %% [markdown]
# #### 1.Display Top 10 Rows of The Dataset

# %%
dt.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# #### 2. Check Last 10 Rows of The Dataset

# %%
dt.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %% [markdown]
# #### 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
b = dt.shape
print('Number of the Rows:',b[0])
print('Number of the Columns:',b[1])
# Out:
# Number of the Rows: 48842
# Number of the Columns: 15

# %% [markdown]
# #### 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# #### 5. Fetch Random Sample From the Dataset (50%)

# %%
dt.sample(frac=0.50)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 42307   34       Private  141118     Bachelors               13
# 45741   45  Self-emp-inc   40666   Prof-school               15
# 29837   32             ?  227160  Some-college               10
# 40      65       Private  136384       Masters               14
# 14970   42  Self-emp-inc  165981  Some-college               10
# ...    ...           ...     ...           ...              ...
# 13775   34       Private  123429  Some-college               10
# 1344    26       Private  160307       Masters               14
# 22446   51       Private   30008       HS-grad                9
# 35982   23       Private  102942     Bachelors               13
# 47167   37       Private  170020       HS-grad                9
#
#               marital-status        occupation   relationship   race  gender  \
# 42307  Married-spouse-absent    Prof-specialty  Not-in-family  White  Female
# ...

# %% [markdown]
# #### 6.Check Null Values In The Dataset

# %%
dt.isnull().sum()    # row wise errors
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
dt.isnull().sum(axis=1)   # columns wise errors
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48837    0
# 48838    0
# 48839    0
# 48840    0
# 48841    0
# Length: 48842, dtype: int64

# %%
import seaborn as sn

# %%
sn.heatmap(dt.isnull())    # if we see any null values it show white spot
# Out:
# <Axes: >

# %% [markdown]
# #### 7.Perform Data Cleaning [ Replace '?' with NaN ]

# %%
dt.head(10)   # here we can see ? this type of values in data
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18               NaN  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29               NaN  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
dt.replace('?',np.NaN,inplace=True)  # we are replacing the ? symbool to NaN value

# %%
dt.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18               NaN  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29               NaN  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# #### 8. Drop all The Missing Values

# %%
dt.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
dt.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        2
#         ..
# 48837    0
# 48838    0
# 48839    0
# 48840    0
# 48841    0
# Length: 48842, dtype: int64

# %%
sn.heatmap(dt.isnull())
# Out:
# <Axes: >

# %%
dt.dropna(how='any', inplace=True)

# %%
dt.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
sn.heatmap(dt.isnull())
# Out:
# <Axes: >

# %%
dt.shape
# Out:
# (45222, 15)

# %% [markdown]
# #### 9. Check For Duplicate Data and Drop Them

# %%
dt.duplicated().any()   # check there is any duplicates values in data
# Out:
# True

# %%
dt.drop_duplicates(inplace=True)

# %%
dt.shape
# Out:
# (45175, 15)

# %% [markdown]
# #### 10.get overall Statistics about the dataset

# %%
dt.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  45175.000000  4.517500e+04     45175.000000  45175.000000
# mean      38.556170  1.897388e+05        10.119314   1102.576270
# std       13.215349  1.056524e+05         2.551740   7510.249876
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.173925e+05         9.000000      0.000000
# 50%       37.000000  1.783120e+05        10.000000      0.000000
# 75%       47.000000  2.379030e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  45175.000000    45175.000000
# mean      88.687593       40.942512
# std      405.156611       12.007730
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
dt.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   45175.000000     45175  4.517500e+04     45175     45175.000000
# unique           NaN         7           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33262           NaN     14770              NaN
# mean       38.556170       NaN  1.897388e+05       NaN        10.119314
# std        13.215349       NaN  1.056524e+05       NaN         2.551740
# min        17.000000       NaN  1.349200e+04       NaN         1.000000
# 25%        28.000000       NaN  1.173925e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783120e+05       NaN        10.000000
# 75%        47.000000       NaN  2.379030e+05       NaN        13.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status    occupation relationship   race gender  \
# ...

# %% [markdown]
# #### 11. Drop The Columns education-num, capital-gain, and capital-loss

# %%
dt.drop(['educational-num', 'capital-gain', 'capital-loss'],axis=1,inplace=True)

# %%
dt.head(10)
# Out:
#     age         workclass  fnlwgt     education      marital-status  \
# 0    25           Private  226802          11th       Never-married
# 1    38           Private   89814       HS-grad  Married-civ-spouse
# 2    28         Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3    44           Private  160323  Some-college  Married-civ-spouse
# 5    34           Private  198693          10th       Never-married
# 7    63  Self-emp-not-inc  104626   Prof-school  Married-civ-spouse
# 8    24           Private  369667  Some-college       Never-married
# 9    55           Private  104996       7th-8th  Married-civ-spouse
# 10   65           Private  184454       HS-grad  Married-civ-spouse
# 11   36       Federal-gov  212465     Bachelors  Married-civ-spouse
#
#            occupation   relationship   race  gender  hours-per-week  \
# 0   Machine-op-inspct      Own-child  Black    Male              40
# 1     Farming-fishing        Husband  White    Male              50
# ...

# %% [markdown]
# ##  Univariate analysis?

# %% [markdown]
# #### 12. What Is The Distribution of Age Column?

# %%
dt.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
dt.describe()
# Out:
#                 age        fnlwgt  hours-per-week
# count  45175.000000  4.517500e+04    45175.000000
# mean      38.556170  1.897388e+05       40.942512
# std       13.215349  1.056524e+05       12.007730
# min       17.000000  1.349200e+04        1.000000
# 25%       28.000000  1.173925e+05       40.000000
# 50%       37.000000  1.783120e+05       40.000000
# 75%       47.000000  2.379030e+05       45.000000
# max       90.000000  1.490400e+06       99.000000

# %%
dt['age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# #### 13. Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method

# %%
sum((dt['age'] >= 17) & (dt['age'] <= 48 ))
# Out:
# 34858

# %%
sum(dt['age'].between(17,48))
# Out:
# 34858

# %% [markdown]
# #### 14. What is The Distribution of Workclass Column?

# %%
dt['workclass'].describe()
# Out:
# count       45175
# unique          7
# top       Private
# freq        33262
# Name: workclass, dtype: object

# %% [markdown]
# #### 15. How Many Persons Having Bachelors and Masters Degree?

# %%
Filters1 = dt['education'] == 'Bachelors'
Filters2 = dt['education'] == 'Masters'

# %%
dt[Filters1|Filters2]
# Out:
#        age    workclass  fnlwgt  education      marital-status  \
# 11      36  Federal-gov  212465  Bachelors  Married-civ-spouse
# 15      43      Private  346189    Masters  Married-civ-spouse
# 20      34      Private  107914  Bachelors  Married-civ-spouse
# 23      25      Private  220931  Bachelors       Never-married
# 24      25      Private  205947  Bachelors  Married-civ-spouse
# ...    ...          ...     ...        ...                 ...
# 48817   34      Private  160216  Bachelors       Never-married
# 48819   38      Private  139180  Bachelors            Divorced
# 48825   31      Private  199655    Masters            Divorced
# 48834   32      Private  116138    Masters       Never-married
# 48835   53      Private  321865    Masters  Married-civ-spouse
#
#             occupation   relationship                race  gender  \
# 11        Adm-clerical        Husband               White    Male
# 15     Exec-managerial        Husband               White    Male
# ...

# %%
len(dt[Filters1|Filters2])
# Out:
# 10072

# %% [markdown]
# ### 16. Bivariate Analsis

# %%
sn.boxplot(x='income', y='age', data=dt)
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %% [markdown]
# #### 17. Replace Salary Values With 0 and 1

# %%
dt['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
dt['income'].value_counts()
# Out:
# income
# <=50K    33973
# >50K     11202
# Name: count, dtype: int64

# %%
dt['income'].replace('<=50K',0,inplace=True)

# %%
dt['income'].replace('>50K',1,inplace=True)

# %%
dt.head(10)
# Out:
#     age         workclass  fnlwgt     education      marital-status  \
# 0    25           Private  226802          11th       Never-married
# 1    38           Private   89814       HS-grad  Married-civ-spouse
# 2    28         Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3    44           Private  160323  Some-college  Married-civ-spouse
# 5    34           Private  198693          10th       Never-married
# 7    63  Self-emp-not-inc  104626   Prof-school  Married-civ-spouse
# 8    24           Private  369667  Some-college       Never-married
# 9    55           Private  104996       7th-8th  Married-civ-spouse
# 10   65           Private  184454       HS-grad  Married-civ-spouse
# 11   36       Federal-gov  212465     Bachelors  Married-civ-spouse
#
#            occupation   relationship   race  gender  hours-per-week  \
# 0   Machine-op-inspct      Own-child  Black    Male              40
# 1     Farming-fishing        Husband  White    Male              50
# ...

# %% [markdown]
# #### 18. Which Workclass Getting The Highest Salary?

# %%
dt.groupby('workclass')['income'].mean()
# Out:
# workclass
# Federal-gov         0.390469
# Local-gov           0.295161
# Private             0.217816
# Self-emp-inc        0.554407
# Self-emp-not-inc    0.279051
# State-gov           0.267215
# Without-pay         0.095238
# Name: income, dtype: float64

# %%
dt.groupby('workclass')['income'].mean().sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        0.554407
# Federal-gov         0.390469
# Local-gov           0.295161
# Self-emp-not-inc    0.279051
# State-gov           0.267215
# Private             0.217816
# Without-pay         0.095238
# Name: income, dtype: float64

# %% [markdown]
# #### 19.How Has Better Chance To Get Salary greater than 50K Male or Female?

# %%
dt.groupby('gender')['income'].mean().sort_values(ascending=False)
# Out:
# gender
# Male      0.312609
# Female    0.113692
# Name: income, dtype: float64

# %% [markdown]
# #### 20. Covert workclass Columns Datatype To Category Datatype

# %%
dt['workclass'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 45175 entries, 0 to 48841
# Series name: workclass
# Non-Null Count  Dtype
# --------------  -----
# 45175 non-null  object
# dtypes: object(1)
# memory usage: 1.7+ MB

# %%
dt['workclass'] = dt['workclass'].astype('category')

# %%
dt['workclass'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 45175 entries, 0 to 48841
# Series name: workclass
# Non-Null Count  Dtype
# --------------  -----
# 45175 non-null  category
# dtypes: category(1)
# memory usage: 1.4 MB
